# %%
kabupaten = ['Badung', 'Gianyar', 'Karangasem', 'Klungkung', 'Tabanan', 'Bangli']
print(kabupaten)
# Out:
# ['Badung', 'Gianyar', 'Karangasem', 'Klungkung', 'Tabanan', 'Bangli']

# %%
print(kabupaten[3])
print(kabupaten[-1])
# Out:
# Klungkung
# Bangli

# %%
kabupaten[0] = 'Denpasar'
print(kabupaten)
# Out:
# ['Denpasar', 'Gianyar', 'Karangasem', 'Klungkung', 'Tabanan', 'Bangli']

# %%
print(kabupaten[0:4])
# Out:
# ['Denpasar', 'Gianyar', 'Karangasem', 'Klungkung']

# %%
kabupaten[0] = 'Badung'
print(kabupaten)
# Out:
# ['Badung', 'Gianyar', 'Karangasem', 'Klungkung', 'Tabanan', 'Bangli']

# %%
kabupaten.append('Denpasar')
print(kabupaten)
# Out:
# ['Badung', 'Gianyar', 'Karangasem', 'Klungkung', 'Tabanan', 'Bangli', 'Denpasar']

# %%
kabupaten.insert(7,'Solo')
print(kabupaten)
# Out:
# ['Badung', 'Gianyar', 'Karangasem', 'Klungkung', 'Tabanan', 'Bangli', 'Denpasar', 'Solo']

# %%
kabupaten.remove('Denpasar')
print(kabupaten)
# Out:
# ['Badung', 'Gianyar', 'Karangasem', 'Klungkung', 'Tabanan', 'Bangli', 'Solo']

# %%
print('Denpasar' in kabupaten)
# Out:
# False

# %%
print(len(kabupaten))
# Out:
# 7

# %%
kabupaten = ['Badung', 'Gianyar', 'Karangasem', 'Klungkung', 'Tabanan', 'Bangli']
for jenis in kabupaten:
    print(jenis)
# Out:
# Badung
# Gianyar
# Karangasem
# Klungkung
# Tabanan
# Bangli

# %%
i = 0
while i < len(kabupaten):
    print(kabupaten[i])
    i+=1
# Out:
# Badung
# Gianyar
# Karangasem
# Klungkung
# Tabanan
# Bangli

# %%
nama17 = "ratih isaka"
harapan17 = "mendapatkan nilai yang baik"
usaha17 = "belajar yang tekun"
print(f"{nama17} memiliki harapan untuk {harapan17} dengan {usaha17}.")
# Out:
# ratih isaka memiliki harapan untuk mendapatkan nilai yang baik dengan belajar yang tekun.

# %%
hobi17 = "saya hobi membaca komik"
print(hobi17[0:6])
print(hobi17[0:-2])
print(hobi17[3:-1:2])
print(len(hobi17))
hobi17.upper()
hobi17.find("membaca")
hobi17.replace("komik", "novel")
# Out:
# saya h
# saya hobi membaca kom
# ahb ebc oi
# 23
# 'saya hobi membaca novel'

# %%
x=-2
y=3
print(x**y)
print((x*y*x+y)/5)
print((x*9*10)**2)
# Out:
# -8
# 3.0
# 32400

# %%
sks_algo17 = 3
sks_strukbar17 = 2
print(sks_algo17 > -1 and sks_strukbar17 < 5)
print(sks_algo17 < -1 and sks_strukbar17 > 5)
print(sks_algo17 > -1 or sks_strukbar17 > 5)
print(not(sks_algo17 > -1 or sks_strukbar17 > 5))
# Out:
# True
# False
# True
# False

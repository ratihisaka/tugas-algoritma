# %%
print('Selamat datang di Pulau Bali! Pulau dewata yang terkenal akan tempat wisata dan kebudayaannya yang indah.')
tujuan_wisata = input(' \nKamu butuh rekomendasi tempat wisata dari kota/kabupaten mana nih? ')
if tujuan_wisata == 'Badung':
    print('\nBerikut rekomendasi tempat wisata di Kabupaten Badung: \n1. Pantai Pandawa \n2. Pura Luhur Uluwatu \n3. Garuda Wisnu Kencana \n4. Waterbom Bali \n5. Pantai Kuta')
    print('Enjoy your holiday!')
elif tujuan_wisata == 'Gianyar':
    print('\nBerikut rekomendasi tempat wisata di Kabupaten Gianyar: \n1. Bali Safari & Marine Park \n2. Kawasan Sentral Ubud \n3. Air Terjun Kanto Lampo \n4. Kemenuh Butterfly Park \n5. Tegalalang')
    print('Enjoy your holiday!')
elif tujuan_wisata == 'Tabanan':
    print("\nBerikut rekomendasi tempat wisata di Kabupaten Tabanan: \n1. Jatiluwih \n2. Danau Beratan \n3. Kebun Raya Bedugul \n4. The Sila's Agrotourism \n5. Tanah Lot")
    print('Enjoy your holiday!')
elif tujuan_wisata == 'Buleleng':
    print('\nBerikut rekomendasi tempat wisata di Kabupaten Buleleng: \n1. Lovina Beach \n2. Air Terjun Sekumpul \n3. Pulau Menjangan \n4. Air Terjun Pucak Sari \n5. Air Panas Banjar')
    print('Enjoy your holiday!')
elif tujuan_wisata == 'Karangasem':
    print('\nBerikut rekomendasi tempat wisata di Kabupaten Karangasem: \n1. Tirta Gangga \n2. Pura Agung Besakih \n3. Taman Ujung \n4. Virgin Beach \n5. Pantai Bias Tugel')
    print('Enjoy your holiday!')
elif tujuan_wisata == 'Klungkung':
    print('\nBerikut rekomendasi tempat wisata di Kabupaten Klungkung: \n1. Pulau Nusa Lembongan \n2. Kertha Gosa \n3. Tukad Unda \n4. Kelingking Beach \n5. Crystal Bay')
    print('Enjoy your holiday!')
elif tujuan_wisata == 'Jembrana':
    print('\nBerikut rekomendasi tempat wisata di Kabupaten Jembrana: \n1. Taman Nasional Bali Barat \n2. Pantai Medewi \n3. Bunut Bolong \n4. Teluk Gilimanuk \n5. Pura Rambut Siwi')
    print('Enjoy your holiday!')
elif tujuan_wisata == 'Bangli':
    print('\nBerikut rekomendasi tempat wisata di Kabupaten Bangli: \t1. Kawasan Gunung Batur \n2. Puncak Trunyan \n3. Gunung Abang \n4. Desa Penglipuran \n5. Twin Hill')
    print('Enjoy your holiday!')
elif tujuan_wisata == 'Denpasar':
    print('\nBerikut rekomendasi tempat wisata di Kabupaten Denpasar: \n1. Pantai Sanur \n2. Pusat Konservasi Penyu \n3. Manta Point \n4. Pantai Sindhu \n5. Monumen Bajra Sandhi')
    print('Enjoy your holiday!')
else : 
    print('\nHmmm Anda salah memasukkan nama kota/kabupaten di Bali.. Ayo coba lagi!')
# Out:
# Selamat datang di Pulau Bali! Pulau dewata yang terkenal akan tempat wisata dan kebudayaannya yang indah.
#
# Kamu butuh rekomendasi tempat wisata dari kota/kabupaten mana nih?  Labuan Bajo
# Hmmm Anda salah memasukkan nama kota/kabupaten di Bali.. Ayo coba lagi!

# %%
print('Selamat datang di Pulau Bali! Pulau dewata yang terkenal akan tempat wisata dan kebudayaannya yang indah.')
tujuan_wisata = input(' \nKamu butuh rekomendasi tempat wisata dari kota/kabupaten mana nih? ')
if tujuan_wisata == 'Badung':
    print('\nBerikut rekomendasi tempat wisata di Kabupaten Badung: \n1. Pantai Pandawa \n2. Pura Luhur Uluwatu \n3. Garuda Wisnu Kencana \n4. Waterbom Bali \n5. Pantai Kuta')
    print('Enjoy your holiday!')
elif tujuan_wisata == 'Gianyar':
    print('\nBerikut rekomendasi tempat wisata di Kabupaten Gianyar: \n1. Bali Safari & Marine Park \n2. Kawasan Sentral Ubud \n3. Air Terjun Kanto Lampo \n4. Kemenuh Butterfly Park \n5. Tegalalang')
    print('Enjoy your holiday!')
elif tujuan_wisata == 'Tabanan':
    print("\nBerikut rekomendasi tempat wisata di Kabupaten Tabanan: \n1. Jatiluwih \n2. Danau Beratan \n3. Kebun Raya Bedugul \n4. The Sila's Agrotourism \n5. Tanah Lot")
    print('Enjoy your holiday!')
elif tujuan_wisata == 'Buleleng':
    print('\nBerikut rekomendasi tempat wisata di Kabupaten Buleleng: \n1. Lovina Beach \n2. Air Terjun Sekumpul \n3. Pulau Menjangan \n4. Air Terjun Pucak Sari \n5. Air Panas Banjar')
    print('Enjoy your holiday!')
elif tujuan_wisata == 'Karangasem':
    print('\nBerikut rekomendasi tempat wisata di Kabupaten Karangasem: \n1. Tirta Gangga \n2. Pura Agung Besakih \n3. Taman Ujung \n4. Virgin Beach \n5. Pantai Bias Tugel')
    print('Enjoy your holiday!')
elif tujuan_wisata == 'Klungkung':
    print('\nBerikut rekomendasi tempat wisata di Kabupaten Klungkung: \n1. Pulau Nusa Lembongan \n2. Kertha Gosa \n3. Tukad Unda \n4. Kelingking Beach \n5. Crystal Bay')
    print('Enjoy your holiday!')
elif tujuan_wisata == 'Jembrana':
    print('\nBerikut rekomendasi tempat wisata di Kabupaten Jembrana: \n1. Taman Nasional Bali Barat \n2. Pantai Medewi \n3. Bunut Bolong \n4. Teluk Gilimanuk \n5. Pura Rambut Siwi')
    print('Enjoy your holiday!')
elif tujuan_wisata == 'Bangli':
    print('\nBerikut rekomendasi tempat wisata di Kabupaten Bangli: \t1. Kawasan Gunung Batur \n2. Puncak Trunyan \n3. Gunung Abang \n4. Desa Penglipuran \n5. Twin Hill')
    print('Enjoy your holiday!')
elif tujuan_wisata == 'Denpasar':
    print('\nBerikut rekomendasi tempat wisata di Kabupaten Denpasar: \n1. Pantai Sanur \n2. Pusat Konservasi Penyu \n3. Manta Point \n4. Pantai Sindhu \n5. Monumen Bajra Sandhi')
    print('Enjoy your holiday!')
else : 
    print('\nHmmm Anda salah memasukkan nama kota/kabupaten di Bali.. Ayo coba lagi!')
# Out:
# Selamat datang di Pulau Bali! Pulau dewata yang terkenal akan tempat wisata dan kebudayaannya yang indah.
#
# Kamu butuh rekomendasi tempat wisata dari kota/kabupaten mana nih?  Klungkung
# Berikut rekomendasi tempat wisata di Kabupaten Klungkung:
# 1. Pulau Nusa Lembongan
# 2. Kertha Gosa
# 3. Tukad Unda
# 4. Kelingking Beach
# 5. Crystal Bay
# Enjoy your holiday!

# %%
a = 0
b = 17
while a < 8:
    print(a * '$' + (b-a) * ' ' + a * '$')
    a += 1
    b -= 1
    
a = 8
b = 9
while a > 0:
    print(a * '$' + (b-a) * ' ' + a * '$')
    a -= 1
    b += 1
# Out:
#
# $               $
# $$             $$
# $$$           $$$
# $$$$         $$$$
# $$$$$       $$$$$
# $$$$$$     $$$$$$
# $$$$$$$   $$$$$$$
# $$$$$$$$ $$$$$$$$
# $$$$$$$   $$$$$$$
# $$$$$$     $$$$$$
# $$$$$       $$$$$
# $$$$         $$$$
# $$$           $$$
# $$             $$
# $               $

# %%
a = 0
b = 10
while a < 8:
    print(b * ' ' + a * '$' + '  ' + a * '$')
    a += 1
    b -= 1
    
a = 8
b = 2
while a > 0:
    print(b * ' ' + a * '$' + '  ' + a * '$')
    a -= 1
    b += 1
# Out:
#
#          $  $
#         $$  $$
#        $$$  $$$
#       $$$$  $$$$
#      $$$$$  $$$$$
#     $$$$$$  $$$$$$
#    $$$$$$$  $$$$$$$
#   $$$$$$$$  $$$$$$$$
#    $$$$$$$  $$$$$$$
#     $$$$$$  $$$$$$
#      $$$$$  $$$$$
#       $$$$  $$$$
#        $$$  $$$
#         $$  $$
#          $  $

# %%
a = 8
b = 9
while a > 0:
    print(a * '$' + (b-a) * ' ' + a * '$')
    a -= 1
    b += 1
    
a = 0
b = 17
while a < 8:
    print(a * '$' + (b-a) * ' ' + a * '$')
    a += 1
    b -= 1
# Out:
# $$$$$$$$ $$$$$$$$
# $$$$$$$   $$$$$$$
# $$$$$$     $$$$$$
# $$$$$       $$$$$
# $$$$         $$$$
# $$$           $$$
# $$             $$
# $               $
#
# $               $
# $$             $$
# $$$           $$$
# $$$$         $$$$
# $$$$$       $$$$$
# $$$$$$     $$$$$$
# $$$$$$$   $$$$$$$

# %%
a = 0
b = 10
while a < 8:
    print(b * ' ' + a * '$' + a * '$')
    a += 1
    b -= 1
    
a = 0
while a < 6:
    print('   '+'$$$$$$$$$$$$$$')
    a += 1
# Out:
#
#          $$
#         $$$$
#        $$$$$$
#       $$$$$$$$
#      $$$$$$$$$$
#     $$$$$$$$$$$$
#    $$$$$$$$$$$$$$
#    $$$$$$$$$$$$$$
#    $$$$$$$$$$$$$$
#    $$$$$$$$$$$$$$
#    $$$$$$$$$$$$$$
#    $$$$$$$$$$$$$$
#    $$$$$$$$$$$$$$

# %%
a = 9
b = 0
while a > 0:
    print('$' + b * ' ' + '$')
    a -= 1
    b += 1
    
a = 0
b = 7
while a < 8:
    print('$' + b * ' ' + '$')
    a += 1
    b -= 1
# Out:
# $$
# $ $
# $  $
# $   $
# $    $
# $     $
# $      $
# $       $
# $        $
# $       $
# $      $
# $     $
# $    $
# $   $
# $  $
# $ $
# $$

# %%
a = 9
b = 0
while a > 0:
    print('$' + b * ' ' + '$'+ a * 2 *' ' + '$'+ b * ' '+ '$')
    a -= 1
    b += 1
    
a = 0
b = 9
while a < 10:
    print('$' + b * ' ' + '$'+ a * 2 *' ' + '$'+ b * ' '+ '$')
    a += 1
    b -= 1
# Out:
# $$                  $$
# $ $                $ $
# $  $              $  $
# $   $            $   $
# $    $          $    $
# $     $        $     $
# $      $      $      $
# $       $    $       $
# $        $  $        $
# $         $$         $
# $        $  $        $
# $       $    $       $
# $      $      $      $
# $     $        $     $
# $    $          $    $
# $   $            $   $
# $  $              $  $
# $ $                $ $
# $$                  $$
